# %%
from PPGCR_utils import EMG, COP
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados_emg = pd.read_csv('./dados/005_ST_DIR_Pós_EMG.txt',sep='\t',names=['M1','M2','M3','M4'],decimal=',')
dados_cop = pd.read_csv('./dados/005_PP_Pós_COP.txt',sep='\t',names=['AP','ML'],decimal=',')

# %%
plt.plot(EMG.filt_emg(dados['M1']),alpha=.1)
plt.plot(dados['M1'],alpha=.1)

# %%
COP.computar_area_elipse_cop(dados_cop['AP'],dados_cop['ML'])
# Out:
# (np.float64(9.6036966470822),
#  np.float64(4.846189877948947),
#  array([[3.91983565e+00, 1.90244737e-09],
#         [1.90244737e-09, 1.53937303e+01]]),
#  np.float64(146.21392392163796))
